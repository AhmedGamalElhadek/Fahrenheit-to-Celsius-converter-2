# %% [markdown]
# # Welcome to Jupyter!

# %% [markdown]
# # Fahrenheit-to-Celsius-converter

# %%
temp = float(input("Enter temperature in Fahrenheit: "))
# Out:
# Enter temperature in Fahrenheit: 50

# %%
celsius = (temp - 32) * 5/9

# %%
print(f"{temp} in Fahrenheit is equal to {celsius} in Celsius")
# Out:
# 50.0 in Fahrenheit is equal to 10.0 in Celsius
